# %%
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks
from matplotlib.pyplot import yticks

# %%
df = pd.read_csv("co22.csv")
df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df['Transmission'].value_counts()
# Out:
# Transmission
# AS6     1324
# AS8     1211
# M6       901
# A6       789
# A8       490
# AM7      445
# A9       339
# AS7      319
# AV       295
# M5       193
# AS10     168
# AM6      132
# AV7      118
# AV6      113
# M7        91
# A5        84
# AS9       77
# A4        65
# AM8       62
# A7        53
# AV8       39
# A10       31
# AS5       26
# AV10      11
# AM5        4
# AM9        3
# AS4        2
# Name: count, dtype: int64

# %%
row,col = df.shape
print("No of rows = ",row)
print("No of cols = ",col)
# Out:
# No of rows =  7385
# No of cols =  12

# %%
df.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
df.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
df.shape
# Out:
# (7385, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %% [markdown]
# # EDA

# %%
auto = df[['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)']]

# %%
sns.pairplot(auto)

# %%
list_col1=  auto.select_dtypes(['int']).columns
list_col1
list_col2=auto.select_dtypes(['float']).columns
list_col2
# Out:
# Index(['Engine Size(L)', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)'],
#       dtype='object')

# %%
auto1=df[['Cylinders', 'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)','Engine Size(L)', 'Fuel Consumption City (L/100 km)',
        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)']]
auto1.corr()
# Out:
#                                   Cylinders  Fuel Consumption Comb (mpg)  \
# Cylinders                          1.000000                    -0.719321
# Fuel Consumption Comb (mpg)       -0.719321                     1.000000
# CO2 Emissions(g/km)                0.832644                    -0.907426
# Engine Size(L)                     0.927653                    -0.757854
# Fuel Consumption City (L/100 km)   0.800702                    -0.927059
# Fuel Consumption Hwy (L/100 km)    0.715252                    -0.890638
# Fuel Consumption Comb (L/100 km)   0.780534                    -0.925576
#
#                                   CO2 Emissions(g/km)  Engine Size(L)  \
# Cylinders                                    0.832644        0.927653
# Fuel Consumption Comb (mpg)                 -0.907426       -0.757854
# CO2 Emissions(g/km)                          1.000000        0.851145
# Engine Size(L)                               0.851145        1.000000
# ...

# %%
# Starting machine learning
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(auto1.corr(),annot=True)
plt.show()

# %%
auto
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
# Dimension reduction

# %%
fuel= pd.get_dummies(auto['Fuel Type'], drop_first = False)
fuel
# Out:
#           D      E      N      X     Z
# 0     False  False  False  False  True
# 1     False  False  False  False  True
# 2     False  False  False  False  True
# 3     False  False  False  False  True
# 4     False  False  False  False  True
# ...     ...    ...    ...    ...   ...
# 7380  False  False  False  False  True
# 7381  False  False  False  False  True
# 7382  False  False  False  False  True
# 7383  False  False  False  False  True
# 7384  False  False  False  False  True
#
# [7385 rows x 5 columns]

# %%
auto = pd.concat([auto, fuel], axis = 1)
auto
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
auto = auto.drop(['Make',"Model",'Transmission','Fuel Type','Vehicle Class'],axis = 1)
auto
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# ...

# %%
auto.corr()
# Out:
#                                   Engine Size(L)  Cylinders  \
# Engine Size(L)                          1.000000   0.927653
# Cylinders                               0.927653   1.000000
# Fuel Consumption City (L/100 km)        0.831379   0.800702
# Fuel Consumption Hwy (L/100 km)         0.761526   0.715252
# Fuel Consumption Comb (L/100 km)        0.817060   0.780534
# Fuel Consumption Comb (mpg)            -0.757854  -0.719321
# CO2 Emissions(g/km)                     0.851145   0.832644
# D                                      -0.068055  -0.053873
# E                                       0.164828   0.118302
# N                                       0.003781   0.002451
# X                                      -0.236023  -0.310360
# Z                                       0.186346   0.277499
#
#                                   Fuel Consumption City (L/100 km)  \
# Engine Size(L)                                            0.831379
# ...

# %%
# Starting machine learning
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(auto.corr(),annot=True)
plt.show()

# %%
auto = auto.drop(['N','D'],axis = 1)
auto
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# ...

# %%
auto
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# ...

# %%
from sklearn.model_selection import train_test_split
# We specify this so that the train and test data set always have the same rows, respectively
df_train, df_test = train_test_split(auto, train_size = 0.85, test_size = 0.15, random_state = 1)

# %%
y_train=df_train['CO2 Emissions(g/km)']
x_train=df_train.drop(['CO2 Emissions(g/km)'],axis=1)

# %%
df_train
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 1206             4.4          8                              15.2
# 5576             3.6          6                              13.0
# 781              6.2          8                              18.7
# 3715             5.0          8                              15.5
# 669              3.5          6                              12.2
# ...              ...        ...                               ...
# 905              3.4          6                              11.9
# 5192             2.0          4                               9.3
# 3980             2.0          4                              10.7
# 235              2.4          4                              12.2
# 5157             3.0          6                              11.8
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 1206                              9.8                              12.8
# ...

# %%
df_train
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 1206             4.4          8                              15.2
# 5576             3.6          6                              13.0
# 781              6.2          8                              18.7
# 3715             5.0          8                              15.5
# 669              3.5          6                              12.2
# ...              ...        ...                               ...
# 905              3.4          6                              11.9
# 5192             2.0          4                               9.3
# 3980             2.0          4                              10.7
# 235              2.4          4                              12.2
# 5157             3.0          6                              11.8
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 1206                              9.8                              12.8
# ...

# %%
df_test.shape
# Out:
# (1108, 10)

# %%
from sklearn.linear_model import LinearRegression
# X_train = df_train[['age','bmi','southeast','yes']]

# y_train = df_train['expenses']
# y_train = y_train.astype('int')
# df_test_predict = X_train.iloc[0:1]

# for linear regression
lr = LinearRegression()
lr_model = lr.fit(x_train, y_train)

# #for logistic regression
# from sklearn.linear_model import LogisticRegression
# lg = LogisticRegression()
# lg_model = lg.fit(X_train, y_train)

# # # # # # #for polynomial regression
# from sklearn.preprocessing import PolynomialFeatures
# poly_reg = PolynomialFeatures(degree=2)
# X_poly = poly_reg.fit_transform(X_train)
# # Y_poly = poly_reg.fit_transform(y_train)
# pol_reg = LinearRegression()
# model = pol_reg.fit(X_poly, y_train)
# poly_reg.fit(X_train, y_train)

# %%
# #to dump model
import pickle as pk
filename = 'model.pickle'
pk.dump(lr_model, open(filename, 'wb'))

# %%
data = auto.iloc[300:301]
data
# Out:
#      Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 300             6.4          8                              16.8
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 300                             10.4                              13.9
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)      E      X     Z
# 300                           20                  320  False  False  True

# %%
auto.columns
# Out:
# Index(['Engine Size(L)', 'Cylinders', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)', 'E', 'X', 'Z'],
#       dtype='object')

# %%
actual_salary = data['CO2 Emissions(g/km)']
data = data.drop(['CO2 Emissions(g/km)'],axis = 1)
data
# Out:
#      Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 300             6.4          8                              16.8
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 300                             10.4                              13.9
#
#      Fuel Consumption Comb (mpg)      E      X     Z
# 300                           20  False  False  True

# %%
#linear model
print("Predicted CO2 Emissions(g/km)",lr_model.predict(data))
print("actual CO2 Emissions(g/km)",actual_salary)
# Out:
# Predicted CO2 Emissions(g/km) [323.07102945]
# actual CO2 Emissions(g/km) 300    320
# Name: CO2 Emissions(g/km), dtype: int64

# %%
#train acc
print("Linear regression = ",(lr_model.score(x_train, y_train)*100))
# print("Logistic regression = ",lg_model.score(X_train, y_train)*100)
# print("Polynomial regression = ",pol_reg.score(poly_reg.fit_transform(X_train), y_train)*100)
# Out:
# Linear regression =  99.20178318477882

# %%
#test acc
test_data = df_test
y_test = test_data['CO2 Emissions(g/km)']
X_test = test_data.drop(['CO2 Emissions(g/km)'],axis = 1)

print("Linear regression = ",(lr_model.score(X_test, y_test)*100))
# Out:
# Linear regression =  99.40382600518697

# %%
 print(data)
esize=[int(input('enter your engine size'))for i in range(1)]
cyc=[int(input('enter how many cylinder vehicle is it'))for i in range(1)]
fc_city=[int(input('enter how much fuel consumption in city (L/100km)'))for i in range(1)]
fc_hwy=[int(input('enter how much fuel consumption in highway (L/100km)'))for i in range(1)]
fc_comb=[int(input('enter how much fuel consumption in combination (L/100km)'))for i in range(1)]
fuel_com=[int(input('enter fuel comsumption combination(mpg)'))for i in range(1)]
e=[int(input('enter fuel type 1 for E otherwise 0='))for i in range(1)]
x=[int(input('enter fuel type 1 for X otherwise 0='))for i in range(1)]
z=[int(input('enter fuel type 1 for Z otherwise 0='))for i in range(1)]
df=pd.DataFrame({'Engine Size(L)':esize,'Cylinders':cyc,'Fuel Consumption City (L/100 km)':fc_city,"Fuel Consumption Hwy (L/100 km)":fc_hwy,'Fuel Consumption Comb (L/100 km)':fc_comb,'Fuel Consumption Comb (mpg)':fuel_com,'E':e,'X':x,'Z':z})
print(df)
predicted_emission = lr_model.predict(df)
print('The carbon emission of the specified vehicle is',predicted_emission)
# df
# Out:
#      Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 300             6.4          8                              16.8
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 300                             10.4                              13.9
#
#      Fuel Consumption Comb (mpg)      E      X     Z
# 300                           20  False  False  True
# enter your engine size 2
# enter how many cylinder vehicle is it 2
# enter how much fuel consumption in city (L/100km) 6
# enter how much fuel consumption in highway (L/100km) 6
# enter how much fuel consumption in combination (L/100km) 9
# enter fuel comsumption combination(mpg) 11
# enter fuel type 1 for E otherwise 0= 1
# enter fuel type 1 for X otherwise 0= 0
# enter fuel type 1 for Z otherwise 0= 0
#    Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0               2          2                                 6
#
# ...
